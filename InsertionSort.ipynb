# %%
import matplotlib.pyplot as plt
import random
import time
from array import array

#insertionSort algo
def insertionSort(arr):
    for j in range(1,len(arr)):
        curr=arr[j]
        prev=j-1

        while prev>=0 and arr[prev]>curr:
            arr[prev+1]=arr[prev]
            prev-=1
        arr[prev+1]=curr


# Input sizes to test
input_sizes = [100,200,300,400,500,
               600, 700, 800, 900, 1000,2000,3000,4000,5000,6000,7000]
execution_times = []

# Measure execution time for each input size
for size in input_sizes:
    # Generate a random array of given size
    arr = []
    for _ in range(size):
        num = random.randint(0, size)
        arr.append(num)

    # Record the time taken to sort
    start_time = time.time()
    insertionSort(arr)
    end_time = time.time()

    # Store time in milliseconds
    elapsed_time = (end_time - start_time) * 1000
    execution_times.append(elapsed_time)
    print(f"Size: {size}, Time: {elapsed_time:.4f} ms")

# Extract median n and time
median_idx = len(input_sizes) // 2
median_n = input_sizes[median_idx]
median_time = execution_times[median_idx]
scaling_factor = median_time / (median_n ** 2)

#Calculation of theoretical time
theoretical_times = [(scaling_factor) * (n ** 2) for n in input_sizes]

# Plot the graph
plt.figure(figsize=(10, 6))
plt.plot(input_sizes, execution_times, marker='o',
         linestyle='-', color='blue', label='Insertion Sort O(n²)')
plt.plot(input_sizes, theoretical_times, marker='',
         linestyle='--', color='red', label=' Theoretical O(n²)')
plt.title("Insertion Sort Time Complexity Analysis")
plt.xlabel("Input Size (n)")
plt.ylabel("Execution Time (ms)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Size: 100, Time: 0.0000 ms
# Size: 200, Time: 0.0000 ms
# Size: 300, Time: 0.0000 ms
# Size: 400, Time: 0.0000 ms
# Size: 500, Time: 4.5788 ms
# Size: 600, Time: 4.0045 ms
# Size: 700, Time: 5.7836 ms
# Size: 800, Time: 27.5693 ms
# Size: 900, Time: 31.8751 ms
# Size: 1000, Time: 35.5110 ms
# Size: 2000, Time: 166.4076 ms
# Size: 3000, Time: 362.0429 ms
# Size: 4000, Time: 669.2951 ms
# Size: 5000, Time: 1078.8217 ms
# Size: 6000, Time: 1462.1975 ms
# Size: 7000, Time: 2049.0532 ms
