# %%
import matplotlib.pyplot as plt
import random
import time

# Bubble Sort Algo
def bubble_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        swapped = False
        for j in range(n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
                swapped = True
        if not swapped:
            break


# Input sizes to test
input_sizes = [100,200,300,400,500,
               600, 700, 800, 900, 1000,2000,3000,4000,5000,6000,7000]
execution_times = []

# Measure execution time for each input size
for size in input_sizes:
    # Generate a random array of given size
    arr = []
    for _ in range(size):
        num = random.randint(0, size)
        arr.append(num)

    # Record the time taken to sort
    start_time = time.time()
    bubble_sort(arr)
    end_time = time.time()

    # Store time in milliseconds
    elapsed_time = (end_time - start_time) * 1000
    execution_times.append(elapsed_time)
    print(f"Size: {size}, Time: {elapsed_time:.4f} ms")

# Extract median n and time
median_idx = len(input_sizes) // 2
median_n = input_sizes[median_idx]
median_time = execution_times[median_idx]
scaling_factor = median_time / (median_n ** 2)

#Calculation of theoretical time
theoretical_times = [(scaling_factor) * (n ** 2) for n in input_sizes]

# Plot the graph
plt.figure(figsize=(10, 6))
plt.plot(input_sizes, execution_times, marker='o',
         linestyle='-', color='blue', label='Bubble Sort O(n²)')
plt.plot(input_sizes, theoretical_times, marker='',
         linestyle='--', color='red', label=' Theoretical O(n²)')
plt.title("Bubble Sort Time Complexity Analysis")
plt.xlabel("Input Size (n)")
plt.ylabel("Execution Time (ms)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Size: 100, Time: 0.0000 ms
# Size: 200, Time: 17.7243 ms
# Size: 300, Time: 0.0000 ms
# Size: 400, Time: 14.8129 ms
# Size: 500, Time: 34.0919 ms
# Size: 600, Time: 37.3297 ms
# Size: 700, Time: 31.7261 ms
# Size: 800, Time: 65.8293 ms
# Size: 900, Time: 77.0769 ms
# Size: 1000, Time: 86.9687 ms
# Size: 2000, Time: 418.9615 ms
# Size: 3000, Time: 950.5064 ms
# Size: 4000, Time: 1657.9480 ms
# Size: 5000, Time: 2649.0309 ms
# Size: 6000, Time: 3727.0331 ms
# Size: 7000, Time: 5112.5214 ms
